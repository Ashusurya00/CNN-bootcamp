# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img =  cv2.imread(r"C:\Users\aashutosh\OneDrive\Attachments\Desktop\training\happy\3-habits-happy-people-01.jpeg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img =  cv2.imread(r'C:\Users\aashutosh\OneDrive\Attachments\Desktop\training\happy\3-habits-happy-people-01.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (340, 600, 3)

# %%
plt.imshow(img)

# %%
img
# Out:
# array([[[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 17,   3,  74],
#         [ 15,   2,  70],
#         [ 13,   2,  65],
#         ...,
#         [239, 239, 233],
#         [239, 239, 233],
#         [239, 239, 233]],
#
#        [[ 14,   0,  71],
#         [ 12,   0,  67],
#         [  9,   0,  61],
#         ...,
#         [239, 239, 233],
#         [239, 239, 233],
#         [239, 239, 233]],
#
#        [[ 12,   0,  69],
#         [ 10,   0,  65],
#         [  7,   0,  59],
# ...

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r"C:\Users\aashutosh\OneDrive\Attachments\Desktop\training\happy\3-habits-happy-people-01.jpeg", cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (340, 600)

# %%
img_gray
# Out:
# array([[253, 253, 253, ..., 255, 255, 255],
#        [253, 253, 253, ..., 255, 255, 255],
#        [253, 253, 253, ..., 255, 255, 255],
#        ...,
#        [ 26,  24,  22, ..., 237, 237, 237],
#        [ 23,  21,  18, ..., 237, 237, 237],
#        [ 21,  19,  16, ..., 238, 237, 237]], dtype=uint8)

# %%
img_gray.min()
# Out:
# np.uint8(0)

# %%
img_gray.max()
# Out:
# np.uint8(255)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap = 'magma') # try with green

# %%
#plt.imshow(img_gray, cmap = 'green')
plt.imshow(img_gray, cmap = 'Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (340, 600, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(600,500)) # 600 -width & 500- height

# %%
plt.imshow(fix_img_1)

# %%
fix_img.shape
# Out:
# (340, 600, 3)

# %%
w_ratio = 0.3
h_ratio = 0.3

# %%
fix_img_2 = cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2.shape # 50% of the fix_img shape
# Out:
# (102, 180, 3)

# %%
plt.imshow(fix_img_2)

# %%
plt.imshow(fix_img)

# %%
img3 = cv2.flip(fix_img_2,0)
plt.imshow(img3)

# %%
cv2.imwrite('new generate image.jpg',img3)
# Out:
# True
