# %%
import cv2
import numpy as np

# Load body classifier
body_classifier = cv2.CascadeClassifier(
    r"C:\Users\aashutosh\OneDrive\Attachments\Desktop\CNN_notes\12th,  - Intro to cv2\opencv\Haarcascades\haarcascade_fullbody.xml"
)

# Load video file
cap = cv2.VideoCapture(r"C:\Users\aashutosh\OneDrive\Attachments\Desktop\training\17581212-uhd_3840_2160_60fps.mp4")   # put correct path

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame, (800, 500))  # Forces stable window size

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect bodies
    bodies = body_classifier.detectMultiScale(gray, 1.2, 3)

    # Draw rectangles
    for (x, y, w, h) in bodies:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 255), 2)

    # Show frame ONCE (important)
    cv2.imshow("Pedestrians", frame)

    if cv2.waitKey(1) == 13:  # Enter key
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#      10 cap = cv2.VideoCapture(r"C:\Users\aashutosh\OneDrive\Attachments\Desktop\training\17581212-uhd_3840_2160_60fps.mp4")   # put correct path
#      12 while cap.isOpened():
# ---> 13     ret, frame = cap.read()
#      14     if not ret:
#      15         break
#
# KeyboardInterrupt:

# %%
import cv2
import time
import numpy as np

# Create our body classifier
car_classifier = cv2.CascadeClassifier(r'C:\Users\aashutosh\OneDrive\Attachments\Desktop\CNN_notes\12th,  - Intro to cv2\opencv\Haarcascades\haarcascade_car.xml')

# Initiate video capture for video file
cap = cv2.VideoCapture(r"C:\Users\aashutosh\Downloads\3727445-hd_1920_1080_30fps.mp4")


# Loop once video is successfully loaded
while cap.isOpened():
    
    time.sleep(.05)
    # Read first frame
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
   
    # Pass frame to our car classifier
    cars = car_classifier.detectMultiScale(gray, 1.4, 2)
    
    # Extract bounding boxes for any bodies identified
    for (x,y,w,h) in cars:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 255), 2)
        cv2.imshow('Cars', frame)

    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 21
#      18 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      20 # Pass frame to our car classifier
# ---> 21 cars = car_classifier.detectMultiScale(gray, 1.4, 2)
#      23 # Extract bounding boxes for any bodies identified
#      24 for (x,y,w,h) in cars:
#
# KeyboardInterrupt:
